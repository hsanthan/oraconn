# %% [markdown]
# ### Connect to the Database and Open SQL Editor

# %%
from IPython.display import clear_output
from IPython.core.display import display, HTML
from sql_editor_proj.db_util_conn10 import db_util 
# %clear
display(HTML("<style>div.output_scroll { height: 100em; }</style>"))
#display(HTML("<style>.container { width:100% !important; }</style>"))


dbc = db_util()
# Out:
# <style>div.output_scroll { height: 100em; }</style>
# Button(description='Connect', style=ButtonStyle())
# Output()

# %%
from IPython.display import clear_output
from sql_editor_proj.db_platform_conn3 import db_util 
# %clear
dbc = db_util()
# Out:
# Button(description='Get Platform Connections', style=ButtonStyle())
# Output()
